# %% [markdown]
# ### Questions:
# Recently our director is interested to find out if we could predict our revenue based on account managers’ activies.
# Some of his questions are below:
#
# 1. Can we find any good predictor for number of Closures or % fee collection using account manager activities in given dataset?
# 2. Are account manager’s activities a good indicator for revenue?
# 3. Is floating interest a good indicator for revenue?
# 4. Does transaction fee impact revenue?

# %% [markdown]
# ### Import required libraries

# %%
# Part 1
import pandas as pd
import numpy as np
# Part 2
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# Part 3
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Step 1: Extract - Transform - Loading

# %% [markdown]
# ## Data extraction

# %%
# Read data file revenue.csv which download from company dashboard with pandas
df=pd.read_csv('revenue.csv')

# %%
# check the data quickly to make sure it is the right file
df.tail()
# Out:
#             Year Month  A Status Account Count  \
# 329          NaN   May                    5073
# 330          NaN  June                    5072
# 331          NaN  July                    5057
# 332   2020 Total   NaN                   60980
# 333  Grand Total   NaN                 1862464
#
#      Annual Review Month Unique Count  Service Month Unique Count  \
# 329                                12                        2576
# 330                                39                        2460
# 331                                75                        2643
# 332                               361                       16316
# 333                             34337                      691530
#
#               TFG  Fee Collected %  Frequent Trading Customer Partner Count  \
# 329  3.192582e+05         0.620230                                     3494
# 330  4.434937e+05         0.738423                                     4260
# 331  5.756627e+05         0.816795                                     5305
# 332  2.816847e+06         0.598382                                    31591
# 333  2.326754e+08         0.754963                                  3230770
#
#      Activity Email Count  Activity Left Message Count  ...  Sales Volume  \
# 329                 551.0                        968.0  ...  2.232797e+06
# 330                 466.0                        715.0  ...  3.067886e+06
# 331                 597.0                        951.0  ...  3.928258e+06
# 332                3301.0                       6102.0  ...  1.945326e+07
# 333              161763.0                     248038.0  ...  1.830398e+09
#
#      TV Transaction Processed Count  Closure Count  Billable Month Volume  \
# 329                            7394           19.0           4.507436e+06
# 330                           10369           27.0           6.135884e+06
# 331                           12323           30.0           8.053953e+06
# 332                           70167            NaN           3.968876e+07
# 333                         7842432        21447.0           3.736002e+09
#
#      Traded100 Account Count  Traded1000 Account Count  \
# 329                     1773                       802
# 330                     1985                       978
# 331                     2097                      1151
# 332                    13799                      6629
# 333                   976766                    593887
#
#      Traded200 Account Count  Traded500 Account Count  \
# 329                     1521                     1119
# 330                     1742                     1351
# 331                     1907                     1522
# 332                    12112                     9235
# 333                   903759                   755072
#
#      Trading Customer Partner Count  Closing Available Balance
# 329                            5267               9.014108e+07
# 330                            6841               8.947853e+07
# 331                            7997               8.926536e+07
# 332                           46898               7.225113e+08
# 333                         5341020               2.013616e+10
#
# [5 rows x 28 columns]

# %%
# check all columns we have
df.columns
# Out:
# Index(['Year', 'Month', 'A Status Account Count',
#        'Annual Review Month Unique Count', 'Service Month Unique Count', 'TFG',
#        'Fee Collected %', 'Frequent Trading Customer Partner Count',
#        'Activity Email Count', 'Activity Left Message Count',
#        'Annual Review Count', 'Service Count', 'Visit Drop In Count',
#        'Fair Trading Strike Count', 'Visit Service Count', 'Search Count',
#        'Search No Match Count', 'Purchase Volume', 'Sales Volume',
#        'TV Transaction Processed Count', 'Closure Count',
#        'Billable Month Volume', 'Traded100 Account Count',
#        'Traded1000 Account Count', 'Traded200 Account Count',
#        'Traded500 Account Count', 'Trading Customer Partner Count',
#        'Closing Available Balance'],
#       dtype='object')

# %%
# check datatype
df.dtypes
# Out:
# Year                                        object
# Month                                       object
# A Status Account Count                       int64
# Annual Review Month Unique Count             int64
# Service Month Unique Count                   int64
# TFG                                        float64
# Fee Collected %                            float64
# Frequent Trading Customer Partner Count      int64
# Activity Email Count                       float64
# Activity Left Message Count                float64
# Annual Review Count                        float64
# Service Count                              float64
# Visit Drop In Count                        float64
# Fair Trading Strike Count                  float64
# Visit Service Count                        float64
# Search Count                               float64
# Search No Match Count                      float64
# Purchase Volume                            float64
# Sales Volume                               float64
# TV Transaction Processed Count               int64
# Closure Count                              float64
# Billable Month Volume                      float64
# Traded100 Account Count                      int64
# Traded1000 Account Count                     int64
# Traded200 Account Count                      int64
# Traded500 Account Count                      int64
# Trading Customer Partner Count               int64
# Closing Available Balance                  float64
# dtype: object

# %% [markdown]
# ## Data transform

# %% [markdown]
# Datatype is looking good. However we can see our dataset doesn't have proper datetime columns. So we will go ahead and construct a proper datetime columns by filling empty year. Then we will need to remove duplicated row (total row end of each year)

# %%
# Contruct all missing year value by using fill NaN with previous row value
df['Year']=df['Year'].fillna(method='ffill')

# %%
# remove all total columns
df=df[~df.Year.str.contains("Total")]

# %%
# construct year- month columns
df['date']=df['Month'] + " - " + df['Year']
df['date']=pd.to_datetime(df['date'])

# %%
# check our new data
df.tail(5)
# Out:
#      Year  Month  A Status Account Count  Annual Review Month Unique Count  \
# 327  2020  March                    5112                                69
# 328  2020  April                    5015                                 6
# 329  2020    May                    5073                                12
# 330  2020   June                    5072                                39
# 331  2020   July                    5057                                75
#
#      Service Month Unique Count          TFG  Fee Collected %  \
# 327                        2413  459012.3525         0.627050
# 328                        2269  170373.1300         0.766216
# 329                        2576  319258.2300         0.620230
# 330                        2460  443493.7400         0.738423
# 331                        2643  575662.7375         0.816795
#
#      Frequent Trading Customer Partner Count  Activity Email Count  \
# 327                                     4849                 477.0
# 328                                     1892                 423.0
# 329                                     3494                 551.0
# 330                                     4260                 466.0
# 331                                     5305                 597.0
#
#      Activity Left Message Count  ...  TV Transaction Processed Count  \
# 327                        767.0  ...                           11069
# 328                        919.0  ...                            3630
# 329                        968.0  ...                            7394
# 330                        715.0  ...                           10369
# 331                        951.0  ...                           12323
#
#      Closure Count  Billable Month Volume  Traded100 Account Count  \
# 327           23.0            6509895.810                     2095
# 328           20.0            2298004.410                     1215
# 329           19.0            4507435.560                     1773
# 330           27.0            6135883.593                     1985
# 331           30.0            8053952.985                     2097
#
#      Traded1000 Account Count  Traded200 Account Count  \
# 327                      1011                     1879
# 328                       482                     1029
# 329                       802                     1521
# 330                       978                     1742
# 331                      1151                     1907
#
#      Traded500 Account Count  Trading Customer Partner Count  \
# 327                     1438                            7434
# 328                      728                            2772
# 329                     1119                            5267
# 330                     1351                            6841
# 331                     1522                            7997
#
#      Closing Available Balance       date
# 327                90783901.22 2020-03-01
# 328                90527026.22 2020-04-01
# 329                90141084.02 2020-05-01
# 330                89478534.02 2020-06-01
# 331                89265359.03 2020-07-01
#
# [5 rows x 29 columns]

# %% [markdown]
# Next, we will go ahead and check for all columns with NaN values

# %%
# check for any columns with NaN value
df.loc[:, df.isna().any()]
# Out:
#      Activity Email Count  Activity Left Message Count  Annual Review Count  \
# 0                     NaN                          NaN                  NaN
# 1                     NaN                          NaN                  NaN
# 2                     NaN                          NaN                  NaN
# 3                     NaN                          NaN                  NaN
# 4                     NaN                          NaN                  NaN
# ..                    ...                          ...                  ...
# 327                 477.0                        767.0                 70.0
# 328                 423.0                        919.0                  6.0
# 329                 551.0                        968.0                 12.0
# 330                 466.0                        715.0                 39.0
# 331                 597.0                        951.0                 75.0
#
#      Service Count  Visit Drop In Count  Fair Trading Strike Count  \
# 0              NaN                  NaN                        NaN
# 1              NaN                  NaN                        NaN
# 2              NaN                  NaN                        NaN
# 3              NaN                  NaN                        NaN
# 4              NaN                  NaN                        NaN
# ..             ...                  ...                        ...
# 327         3028.0                 28.0                        0.0
# 328         2713.0                  0.0                        0.0
# 329         3278.0                  7.0                        0.0
# 330         3281.0                 22.0                        0.0
# 331         3550.0                 55.0                        0.0
#
#      Visit Service Count  Search Count  Search No Match Count  Closure Count
# 0                    NaN           NaN                    NaN           10.0
# 1                    NaN           NaN                    NaN           15.0
# 2                    NaN           NaN                    NaN           35.0
# 3                    NaN           NaN                    NaN           20.0
# 4                    NaN           NaN                    NaN           28.0
# ..                   ...           ...                    ...            ...
# 327                253.0       56236.0                 3882.0           23.0
# 328                  9.0       11293.0                 1189.0           20.0
# 329                 68.0       57704.0                 3287.0           19.0
# 330                220.0       90247.0                 4702.0           27.0
# 331                272.0       98885.0                 4292.0           30.0
#
# [307 rows x 10 columns]

# %%
# Loop through all columns and calculate total missing values NaN each columns
for col in df.columns:
    print (col,' has a total of ',df[col].isna().sum(),' NaN values')
# Out:
# Year  has a total of  0  NaN values
# Month  has a total of  0  NaN values
# A Status Account Count  has a total of  0  NaN values
# Annual Review Month Unique Count  has a total of  0  NaN values
# Service Month Unique Count  has a total of  0  NaN values
# TFG  has a total of  0  NaN values
# Fee Collected %  has a total of  0  NaN values
# Frequent Trading Customer Partner Count  has a total of  0  NaN values
# Activity Email Count  has a total of  62  NaN values
# Activity Left Message Count  has a total of  62  NaN values
# Annual Review Count  has a total of  62  NaN values
# Service Count  has a total of  62  NaN values
# Visit Drop In Count  has a total of  62  NaN values
# Fair Trading Strike Count  has a total of  62  NaN values
# Visit Service Count  has a total of  62  NaN values
# Search Count  has a total of  250  NaN values
# Search No Match Count  has a total of  250  NaN values
# Purchase Volume  has a total of  0  NaN values
# Sales Volume  has a total of  0  NaN values
# TV Transaction Processed Count  has a total of  0  NaN values
# Closure Count  has a total of  1  NaN values
# Billable Month Volume  has a total of  0  NaN values
# Traded100 Account Count  has a total of  0  NaN values
# Traded1000 Account Count  has a total of  0  NaN values
# Traded200 Account Count  has a total of  0  NaN values
# Traded500 Account Count  has a total of  0  NaN values
# Trading Customer Partner Count  has a total of  0  NaN values
# Closing Available Balance  has a total of  0  NaN values
# date  has a total of  0  NaN values

# %%
# Get % of missing value over total rows
print (df['Search No Match Count'].isna().values.sum()/len(df))
# Out:
# 0.8143322475570033

# %% [markdown]
# As we can see Search columns has the highest number of NaN due to this tool only came availalbe in 2016.
# In this study, we will decide to remove this feature due to more than 80% of values are missing.

# %%
# delete this feature
del df['Search Count']
del df['Search No Match Count']

# %%
# Loop through all columns and calculate total missing values NaN each columns
for col in df.columns:
    print (col,' has a total of ',df[col].isna().sum(),' NaN values')
# Out:
# Year  has a total of  0  NaN values
# Month  has a total of  0  NaN values
# A Status Account Count  has a total of  0  NaN values
# Annual Review Month Unique Count  has a total of  0  NaN values
# Service Month Unique Count  has a total of  0  NaN values
# TFG  has a total of  0  NaN values
# Fee Collected %  has a total of  0  NaN values
# Frequent Trading Customer Partner Count  has a total of  0  NaN values
# Activity Email Count  has a total of  62  NaN values
# Activity Left Message Count  has a total of  62  NaN values
# Annual Review Count  has a total of  62  NaN values
# Service Count  has a total of  62  NaN values
# Visit Drop In Count  has a total of  62  NaN values
# Fair Trading Strike Count  has a total of  62  NaN values
# Visit Service Count  has a total of  62  NaN values
# Purchase Volume  has a total of  0  NaN values
# Sales Volume  has a total of  0  NaN values
# TV Transaction Processed Count  has a total of  0  NaN values
# Closure Count  has a total of  1  NaN values
# Billable Month Volume  has a total of  0  NaN values
# Traded100 Account Count  has a total of  0  NaN values
# Traded1000 Account Count  has a total of  0  NaN values
# Traded200 Account Count  has a total of  0  NaN values
# Traded500 Account Count  has a total of  0  NaN values
# Trading Customer Partner Count  has a total of  0  NaN values
# Closing Available Balance  has a total of  0  NaN values
# date  has a total of  0  NaN values

# %%
# Get % of missing value over total rows
print (df['Activity Email Count'].isna().values.sum()/len(df))
# Out:
# 0.20195439739413681

# %% [markdown]
# The next features has 21% of values missing is Account manager activities. This can be explained by in the first 5 years from 1995 to 2000, the company hasn't got the KPI system for account manager and it only became available in 2000.
# In this study, we will not taking the approach to replace missing values by mean() or median of this feature due to the fact that in the first few years, data quality might not be as accurate as after 2000. So we will remove this NaN value and only study from 2000 towards.

# %%
# check our data before remove all NaN values
df.tail()
# Out:
#      Year  Month  A Status Account Count  Annual Review Month Unique Count  \
# 327  2020  March                    5112                                69
# 328  2020  April                    5015                                 6
# 329  2020    May                    5073                                12
# 330  2020   June                    5072                                39
# 331  2020   July                    5057                                75
#
#      Service Month Unique Count          TFG  Fee Collected %  \
# 327                        2413  459012.3525         0.627050
# 328                        2269  170373.1300         0.766216
# 329                        2576  319258.2300         0.620230
# 330                        2460  443493.7400         0.738423
# 331                        2643  575662.7375         0.816795
#
#      Frequent Trading Customer Partner Count  Activity Email Count  \
# 327                                     4849                 477.0
# 328                                     1892                 423.0
# 329                                     3494                 551.0
# 330                                     4260                 466.0
# 331                                     5305                 597.0
#
#      Activity Left Message Count  ...  TV Transaction Processed Count  \
# 327                        767.0  ...                           11069
# 328                        919.0  ...                            3630
# 329                        968.0  ...                            7394
# 330                        715.0  ...                           10369
# 331                        951.0  ...                           12323
#
#      Closure Count  Billable Month Volume  Traded100 Account Count  \
# 327           23.0            6509895.810                     2095
# 328           20.0            2298004.410                     1215
# 329           19.0            4507435.560                     1773
# 330           27.0            6135883.593                     1985
# 331           30.0            8053952.985                     2097
#
#      Traded1000 Account Count  Traded200 Account Count  \
# 327                      1011                     1879
# 328                       482                     1029
# 329                       802                     1521
# 330                       978                     1742
# 331                      1151                     1907
#
#      Traded500 Account Count  Trading Customer Partner Count  \
# 327                     1438                            7434
# 328                      728                            2772
# 329                     1119                            5267
# 330                     1351                            6841
# 331                     1522                            7997
#
#      Closing Available Balance       date
# 327                90783901.22 2020-03-01
# 328                90527026.22 2020-04-01
# 329                90141084.02 2020-05-01
# 330                89478534.02 2020-06-01
# 331                89265359.03 2020-07-01
#
# [5 rows x 27 columns]

# %%
# Remove all NaN value
df = df[~df.isna().any(axis=1)]

# %%
# check final data shape
df.shape
# Out:
# (245, 27)

# %%
# Now we check for first 5 and bottom 5 rows of dataframe
df.head()
# Out:
#     Year     Month  A Status Account Count  Annual Review Month Unique Count  \
# 66  2000  February                    3345                                 0
# 68  2000     April                    3343                                 0
# 69  2000       May                    3591                                 0
# 70  2000      June                    3703                                 0
# 71  2000      July                    4148                                 0
#
#     Service Month Unique Count        TFG  Fee Collected %  \
# 66                           0  512760.98         0.795961
# 68                           0  489407.27         0.751309
# 69                           0  705151.59         0.795144
# 70                           0  599442.24         0.790643
# 71                           0  705770.43         0.765749
#
#     Frequent Trading Customer Partner Count  Activity Email Count  \
# 66                                     7258                   0.0
# 68                                     7448                   6.0
# 69                                     8188                  35.0
# 70                                     6694                  18.0
# 71                                     9104                  10.0
#
#     Activity Left Message Count  ...  TV Transaction Processed Count  \
# 66                          0.0  ...                           17907
# 68                          0.0  ...                           17209
# 69                          0.0  ...                           22837
# 70                          0.0  ...                           21423
# 71                          0.0  ...                           21941
#
#     Closure Count  Billable Month Volume  Traded100 Account Count  \
# 66           57.0           9.303623e+06                     2243
# 68           30.0           8.906479e+06                     2306
# 69           64.0           1.176434e+07                     2529
# 70           57.0           1.042658e+07                     2472
# 71           50.0           1.180272e+07                     2778
#
#     Traded1000 Account Count  Traded200 Account Count  \
# 66                      1424                     2110
# 68                      1489                     2179
# 69                      1776                     2407
# 70                      1617                     2323
# 71                      1776                     2606
#
#     Traded500 Account Count  Trading Customer Partner Count  \
# 66                     1786                           12592
# 68                     1828                           12628
# 69                     2119                           15858
# 70                     2002                           15404
# 71                     2232                           16021
#
#     Closing Available Balance       date
# 66                24587851.24 2000-02-01
# 68                26308623.30 2000-04-01
# 69                28129949.79 2000-05-01
# 70                28490604.70 2000-06-01
# 71                29399982.36 2000-07-01
#
# [5 rows x 27 columns]

# %%
# check last 5 rows
df.tail()
# Out:
#      Year  Month  A Status Account Count  Annual Review Month Unique Count  \
# 327  2020  March                    5112                                69
# 328  2020  April                    5015                                 6
# 329  2020    May                    5073                                12
# 330  2020   June                    5072                                39
# 331  2020   July                    5057                                75
#
#      Service Month Unique Count          TFG  Fee Collected %  \
# 327                        2413  459012.3525         0.627050
# 328                        2269  170373.1300         0.766216
# 329                        2576  319258.2300         0.620230
# 330                        2460  443493.7400         0.738423
# 331                        2643  575662.7375         0.816795
#
#      Frequent Trading Customer Partner Count  Activity Email Count  \
# 327                                     4849                 477.0
# 328                                     1892                 423.0
# 329                                     3494                 551.0
# 330                                     4260                 466.0
# 331                                     5305                 597.0
#
#      Activity Left Message Count  ...  TV Transaction Processed Count  \
# 327                        767.0  ...                           11069
# 328                        919.0  ...                            3630
# 329                        968.0  ...                            7394
# 330                        715.0  ...                           10369
# 331                        951.0  ...                           12323
#
#      Closure Count  Billable Month Volume  Traded100 Account Count  \
# 327           23.0            6509895.810                     2095
# 328           20.0            2298004.410                     1215
# 329           19.0            4507435.560                     1773
# 330           27.0            6135883.593                     1985
# 331           30.0            8053952.985                     2097
#
#      Traded1000 Account Count  Traded200 Account Count  \
# 327                      1011                     1879
# 328                       482                     1029
# 329                       802                     1521
# 330                       978                     1742
# 331                      1151                     1907
#
#      Traded500 Account Count  Trading Customer Partner Count  \
# 327                     1438                            7434
# 328                      728                            2772
# 329                     1119                            5267
# 330                     1351                            6841
# 331                     1522                            7997
#
#      Closing Available Balance       date
# 327                90783901.22 2020-03-01
# 328                90527026.22 2020-04-01
# 329                90141084.02 2020-05-01
# 330                89478534.02 2020-06-01
# 331                89265359.03 2020-07-01
#
# [5 rows x 27 columns]
